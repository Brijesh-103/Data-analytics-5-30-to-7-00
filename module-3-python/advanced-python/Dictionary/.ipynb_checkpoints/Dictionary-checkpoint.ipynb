# %%
employee = {1:"brijesh",2:"krish",3:"Het",4:"Divyang"}
#itretion key
for k in employee:
    print(k)
# Out:
# 1
# 2
# 3
# 4

# %%
#itretion velue
for k in employee.values():
    print(k)
# Out:
# brijesh
# krish
# Het
# Divyang

# %%
for i in employee: 
    print(employee[i])
# Out:
# brijesh
# krish
# Het
# Divyang
