# %%
name = input("Enter your name: ")
print("Your name is : ",name  )
# Out:
# Enter your name:  Brijesh
# Your name is :  Brijesh

# %%
a = 0
b = 0
c = 0 
while c == 0:
    o = input ("select your opretion 1= +, 2= - , 3 = /, 4 = * :")
    if o == 1:
        a = input("Enter your 1st velue: ")
        b = input("Enter your 2nd velue: ")
        Print("Your Sum of", a ," & ", b, " is :", a + b )
    else:
        if o == 2:
        a = input("Enter your 1st velue: ")
        b = input("Enter your 2nd velue: ")
        Print("Your Sub of", a ," & ", b, " is :", a - b )
    else: if o == 3:
        a = input("Enter your 1st velue: ")
        b = input("Enter your 2nd velue: ")
        Print("Your Div of", a ," & ", b, " is :", a / b )
    else if o == 4:
        a = input("Enter your 1st velue: ")
        b = input("Enter your 2nd velue: ")
        Print("Your Mul of", a ," & ", b, " is :", a * b )
    else :
        c == 1
# Out:
#   Cell In[6], line 10
#     else if o == 2:
#          ^
# SyntaxError: expected ':'
