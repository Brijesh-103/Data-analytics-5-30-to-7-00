# %%
name = input("Enter your name: ")
print("Your name is : ",name  )
# Out:
# Enter your name:  Brijesh
# Your name is :  Brijesh

# %%
a = 0
b = 0
c = 0
while c == 0:
    o = int(input ("select your opretion 1= +, 2= - , 3 = /, 4 = * :"))
    if o == 1:
        a = int(input("Enter your 1st velue: "))
        b = int(input("Enter your 2nd velue: "))
        print("Your Sum of", a ," & ", b, " is :", a + b )
    elif o == 2:
        a = int(input("Enter your 1st velue: "))
        b = int(input("Enter your 2nd velue: "))
        print("Your Sub of", a ," & ", b, " is :", a - b )
    elif o == 3:
        a = int(input("Enter your 1st velue: "))
        b = int(input("Enter your 2nd velue: "))
        print("Your Div of", a ," & ", b, " is :", a / b )
    elif o == 4:
        a = int(input("Enter your 1st velue: "))
        b = int(input("Enter your 2nd velue: "))
        print("Your Mul of", a ," & ", b, " is :", a * b )
    else:        
        print("Invalid opretion")
    c = input("Do you want to continue ? (y/n) :")
    if c == "y":
        c = 0
    else:        
        c = 1 
print("Good bye ")
# Out:
# Your Sum of 20  &  30  is : 50
# Good bye
